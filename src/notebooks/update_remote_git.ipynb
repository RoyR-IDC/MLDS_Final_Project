# %% [markdown]
# # Update remote git

# %%
import os
from google.colab import drive

# mount drive
drive.mount('/content/drive')

# go to relevant project folder
path_to_repo = '/content/drive/MyDrive/MLDS_Final_Project'
os.chdir(path_to_repo)

# %%
# get latest code from git
# !git switch development
# !git status
# !git pull

# %%
# ## If "pull" failed because of local changes

# # 1. Discard all changes in tracked files
# !git reset --hard
# # 2. Remove all untracked files and directories
# !git clean -fd
